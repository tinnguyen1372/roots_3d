# %%
import os
# !git clone https://github.com/tinnguyen1372/roots_3d.git
# Out:
# Cloning into 'roots_3d'...
# remote: Enumerating objects: 45076, done.
# remote: Counting objects: 100% (297/297), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 45076 (delta 19), reused 280 (delta 9), pack-reused 44779 (from 3)
# Receiving objects: 100% (45076/45076), 259.99 MiB | 28.77 MiB/s, done.
# Resolving deltas: 100% (39524/39524), done.
# Updating files: 100% (1871/1871), done.

# %%
os.chdir('/kaggle/working/roots_3d/')

# !pip install -r requirements.txt

# !python setup.py build
# !python setup.py install
# Out:
# Collecting anyio==3.6.2 (from -r requirements.txt (line 1))
#   Downloading anyio-3.6.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting argon2-cffi==21.3.0 (from -r requirements.txt (line 2))
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (21.2.0)
# Collecting arrow==1.2.3 (from -r requirements.txt (line 4))
#   Downloading arrow-1.2.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting asttokens==2.2.1 (from -r requirements.txt (line 5))
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting attrs==23.1.0 (from -r requirements.txt (line 6))
#   Downloading attrs-23.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.2.0)
# Collecting beautifulsoup4==4.12.2 (from -r requirements.txt (line 8))
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting bleach==6.0.0 (from -r requirements.txt (line 9))
#   Downloading bleach-6.0.0-py3-none-any.whl.metadata (29 kB)
# Collecting cffi==1.15.1 (from -r requirements.txt (line 10))
#   Downloading cffi-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.4.6)
# Collecting comm==0.1.3 (from -r requirements.txt (line 12))
#   Downloading comm-0.1.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting contourpy==1.0.7 (from -r requirements.txt (line 13))
#   Downloading contourpy-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting cycler==0.11.0 (from -r requirements.txt (line 14))
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Collecting Cython==0.29.34 (from -r requirements.txt (line 15))
#   Downloading Cython-0.29.34-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Collecting debugpy==1.6.7 (from -r requirements.txt (line 16))
#   Downloading debugpy-1.6.7-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r requirements.txt (line 17))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (0.7.1)
# Collecting executing==1.2.0 (from -r requirements.txt (line 19))
#   Downloading executing-1.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting fastjsonschema==2.16.3 (from -r requirements.txt (line 20))
#   Downloading fastjsonschema-2.16.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting fonttools==4.39.3 (from -r requirements.txt (line 21))
#   Downloading fonttools-4.39.3-py3-none-any.whl.metadata (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: fqdn==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (1.5.1)
# ERROR: Could not find a version that satisfies the requirement gprMax==3.1.4 (from versions: none)
# ERROR: No matching distribution found for gprMax==3.1.4
# Running 'build_ext --inplace'
# Compiling gprMax/fields_updates_ext.pyx because it changed.
# Compiling gprMax/geometry_primitives_ext.pyx because it changed.
# Compiling gprMax/fractals_generate_ext.pyx because it changed.
# Compiling gprMax/yee_cell_build_ext.pyx because it changed.
# Compiling gprMax/snapshots_ext.pyx because it changed.
# Compiling gprMax/yee_cell_setget_rigid_ext.pyx because it changed.
# Compiling gprMax/geometry_outputs_ext.pyx because it changed.
# Compiling gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.pyx because it changed.
# Compiling gprMax/pml_updates/pml_updates_electric_HORIPML_ext.pyx because it changed.
# Compiling gprMax/pml_updates/pml_updates_electric_MRIPML_ext.pyx because it changed.
# Compiling gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.pyx because it changed.
# [ 1/11] Cythonizing gprMax/fields_updates_ext.pyx
# [ 2/11] Cythonizing gprMax/fractals_generate_ext.pyx
# [ 3/11] Cythonizing gprMax/geometry_outputs_ext.pyx
# [ 4/11] Cythonizing gprMax/geometry_primitives_ext.pyx
# [ 5/11] Cythonizing gprMax/pml_updates/pml_updates_electric_HORIPML_ext.pyx
# [ 6/11] Cythonizing gprMax/pml_updates/pml_updates_electric_MRIPML_ext.pyx
# [ 7/11] Cythonizing gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.pyx
# [ 8/11] Cythonizing gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.pyx
# [ 9/11] Cythonizing gprMax/snapshots_ext.pyx
# [10/11] Cythonizing gprMax/yee_cell_build_ext.pyx
# [11/11] Cythonizing gprMax/yee_cell_setget_rigid_ext.pyx
# running build_ext
# building 'gprMax.fields_updates_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/fields_updates_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/fields_updates_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/fields_updates_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/fields_updates_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.geometry_primitives_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/geometry_primitives_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/geometry_primitives_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/geometry_primitives_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/geometry_primitives_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.fractals_generate_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/fractals_generate_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/fractals_generate_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/fractals_generate_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/fractals_generate_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.yee_cell_build_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/yee_cell_build_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/yee_cell_build_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/yee_cell_build_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/yee_cell_build_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.snapshots_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/snapshots_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/snapshots_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/snapshots_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/snapshots_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.yee_cell_setget_rigid_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/yee_cell_setget_rigid_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/yee_cell_setget_rigid_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/yee_cell_setget_rigid_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/yee_cell_setget_rigid_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.geometry_outputs_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/geometry_outputs_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/geometry_outputs_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/geometry_outputs_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/geometry_outputs_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.pml_updates.pml_updates_magnetic_HORIPML_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.pml_updates.pml_updates_electric_HORIPML_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/pml_updates/pml_updates_electric_HORIPML_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_HORIPML_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_HORIPML_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_HORIPML_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.pml_updates.pml_updates_electric_MRIPML_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/pml_updates/pml_updates_electric_MRIPML_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_MRIPML_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_MRIPML_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_MRIPML_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# building 'gprMax.pml_updates.pml_updates_magnetic_MRIPML_ext' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.c -o build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.o -O3 -w -fopenmp -march=native
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.cpython-311-x86_64-linux-gnu.so -fopenmp
# copying build/lib.linux-x86_64-cpython-311/gprMax/fields_updates_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/geometry_primitives_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/fractals_generate_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/yee_cell_build_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/snapshots_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/yee_cell_setget_rigid_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/geometry_outputs_ext.cpython-311-x86_64-linux-gnu.so -> gprMax
# copying build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_HORIPML_ext.cpython-311-x86_64-linux-gnu.so -> gprMax/pml_updates
# copying build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_HORIPML_ext.cpython-311-x86_64-linux-gnu.so -> gprMax/pml_updates
# copying build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_electric_MRIPML_ext.cpython-311-x86_64-linux-gnu.so -> gprMax/pml_updates
# copying build/lib.linux-x86_64-cpython-311/gprMax/pml_updates/pml_updates_magnetic_MRIPML_ext.cpython-311-x86_64-linux-gnu.so -> gprMax/pml_updates
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing gprMax.egg-info/PKG-INFO
# writing dependency_links to gprMax.egg-info/dependency_links.txt
# writing requirements to gprMax.egg-info/requires.txt
# writing top-level names to gprMax.egg-info/top_level.txt
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*.DS_Store' found anywhere in distribution
# adding license file 'LICENSE'
# writing manifest file 'gprMax.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying gprMax/optimisation_taguchi.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/fields_outputs.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/sources.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/snapshots_gpu.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/input_cmds_geometry.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/__main__.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/input_cmd_funcs.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/receivers.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/exceptions.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/grid.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/gprMax.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/fractals.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/input_cmds_file.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/_version.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/__init__.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/input_cmds_singleuse.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/input_cmds_multiuse.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/constants.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/model_build_run.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/fields_updates_gpu.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/utilities.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/geometry_outputs.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/materials.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/waveforms.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/pml.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/snapshots.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying gprMax/source_updates_gpu.py -> build/lib.linux-x86_64-cpython-311/gprMax
# copying tests/analytical_solutions.py -> build/lib.linux-x86_64-cpython-311/tests
# copying tests/test_models.py -> build/lib.linux-x86_64-cpython-311/tests
# copying tests/__init__.py -> build/lib.linux-x86_64-cpython-311/tests
# copying tests/test_experimental.py -> build/lib.linux-x86_64-cpython-311/tests
# copying tests/test_input_cmd_funcs.py -> build/lib.linux-x86_64-cpython-311/tests
# copying tools/plot_source_wave.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/__init__.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/inputfile_old2new.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/convert_png2h5.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/plot_Ascan.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/outputfiles_merge.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/plot_antenna_params.py -> build/lib.linux-x86_64-cpython-311/tools
# copying tools/plot_Bscan.py -> build/lib.linux-x86_64-cpython-311/tools
# copying user_libs/__init__.py -> build/lib.linux-x86_64-cpython-311/user_libs
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'gprMax.__pycache__' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'gprMax.__pycache__' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'gprMax.__pycache__' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'gprMax.__pycache__' to be distributed and are
#         already explicitly excluding 'gprMax.__pycache__' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'gprMax.pml_updates' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'gprMax.pml_updates' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'gprMax.pml_updates' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'gprMax.pml_updates' to be distributed and are
#         already explicitly excluding 'gprMax.pml_updates' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'gprMax.pml_updates.__pycache__' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'gprMax.pml_updates.__pycache__' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'gprMax.pml_updates.__pycache__' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'gprMax.pml_updates.__pycache__' to be distributed and are
#         already explicitly excluding 'gprMax.pml_updates.__pycache__' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking' to be distributed and are
#         already explicitly excluding 'tests.benchmarking' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking.results.cpu.Linux.Dell_PowerEdge_R630' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking.results.cpu.Linux.Dell_PowerEdge_R630' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking.results.cpu.Linux.Dell_PowerEdge_R630' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking.results.cpu.Linux.Dell_PowerEdge_R630' to be distributed and are
#         already explicitly excluding 'tests.benchmarking.results.cpu.Linux.Dell_PowerEdge_R630' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking.results.cpu.Linux.Lenovo_System_x3650_M5' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking.results.cpu.Linux.Lenovo_System_x3650_M5' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking.results.cpu.Linux.Lenovo_System_x3650_M5' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking.results.cpu.Linux.Lenovo_System_x3650_M5' to be distributed and are
#         already explicitly excluding 'tests.benchmarking.results.cpu.Linux.Lenovo_System_x3650_M5' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking.results.cpu.Linux' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking.results.cpu.Linux' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking.results.cpu.Linux' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking.results.cpu.Linux' to be distributed and are
#         already explicitly excluding 'tests.benchmarking.results.cpu.Linux' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking.results.cpu.MacOSX' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking.results.cpu.MacOSX' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking.results.cpu.MacOSX' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking.results.cpu.MacOSX' to be distributed and are
#         already explicitly excluding 'tests.benchmarking.results.cpu.MacOSX' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tests.benchmarking.results.cpu.Windows7.Dell_Z420' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tests.benchmarking.results.cpu.Windows7.Dell_Z420' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tests.benchmarking.results.cpu.Windows7.Dell_Z420' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tests.benchmarking.results.cpu.Windows7.Dell_Z420' to be distributed and are
#         already explicitly excluding 'tests.benchmarking.results.cpu.Windows7.Dell_Z420' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
# ...
# Installing jupyter-nbclassic script to /usr/local/bin
# Installing jupyter-nbclassic-bundlerextension script to /usr/local/bin
# Installing jupyter-nbclassic-extension script to /usr/local/bin
# Installing jupyter-nbclassic-serverextension script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-server-ydoc==0.8.0
# Best match: jupyter-server-ydoc 0.8.0
# Adding jupyter-server-ydoc 0.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-ydoc==0.2.5
# Best match: jupyter-ydoc 0.2.5
# Adding jupyter-ydoc 0.2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-server==2.12.5
# Best match: jupyter-server 2.12.5
# Adding jupyter-server 2.12.5 to easy-install.pth file
# Installing jupyter-server script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyterlab-server==2.28.0
# Best match: jupyterlab-server 2.28.0
# Adding jupyterlab-server 2.28.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-core==5.8.1
# Best match: jupyter-core 5.8.1
# Adding jupyter-core 5.8.1 to easy-install.pth file
# Installing jupyter script to /usr/local/bin
# Installing jupyter-migrate script to /usr/local/bin
# Installing jupyter-troubleshoot script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tornado==6.5.2
# Best match: tornado 6.5.2
# Adding tornado 6.5.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for ipython==7.34.0
# Best match: ipython 7.34.0
# Adding ipython 7.34.0 to easy-install.pth file
# Installing iptest script to /usr/local/bin
# Installing iptest3 script to /usr/local/bin
# Installing ipython script to /usr/local/bin
# Installing ipython3 script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyterlab-widgets==3.0.15
# Best match: jupyterlab-widgets 3.0.15
# Adding jupyterlab-widgets 3.0.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for widgetsnbextension==4.0.15
# Best match: widgetsnbextension 4.0.15
# Adding widgetsnbextension 4.0.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for traitlets==5.7.1
# Best match: traitlets 5.7.1
# Adding traitlets 5.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for comm==0.2.3
# Best match: comm 0.2.3
# Adding comm 0.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pyzmq==26.2.1
# Best match: pyzmq 26.2.1
# Adding pyzmq 26.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nest-asyncio==1.6.0
# Best match: nest-asyncio 1.6.0
# Adding nest-asyncio 1.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for matplotlib-inline==0.1.7
# Best match: matplotlib-inline 0.1.7
# Adding matplotlib-inline 0.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-client==8.6.3
# Best match: jupyter-client 8.6.3
# Adding jupyter-client 8.6.3 to easy-install.pth file
# Installing jupyter-kernel script to /usr/local/bin
# Installing jupyter-kernelspec script to /usr/local/bin
# Installing jupyter-run script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for debugpy==1.8.15
# Best match: debugpy 1.8.15
# Adding debugpy 1.8.15 to easy-install.pth file
# Installing debugpy script to /usr/local/bin
# Installing debugpy-adapter script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for markupsafe==3.0.3
# Best match: markupsafe 3.0.3
# Adding markupsafe 3.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nbclient==0.5.13
# Best match: nbclient 0.5.13
# Adding nbclient 0.5.13 to easy-install.pth file
# Installing jupyter-execute script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for beautifulsoup4==4.13.4
# Best match: beautifulsoup4 4.13.4
# Adding beautifulsoup4 4.13.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for defusedxml==0.7.1
# Best match: defusedxml 0.7.1
# Adding defusedxml 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for testpath==0.6.0
# Best match: testpath 0.6.0
# Adding testpath 0.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pandocfilters==1.5.1
# Best match: pandocfilters 1.5.1
# Adding pandocfilters 1.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for bleach==6.2.0
# Best match: bleach 6.2.0
# Adding bleach 6.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for entrypoints==0.4
# Best match: entrypoints 0.4
# Adding entrypoints 0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nbformat==5.10.4
# Best match: nbformat 5.10.4
# Adding nbformat 5.10.4 to easy-install.pth file
# Installing jupyter-trust script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyterlab-pygments==0.3.0
# Best match: jupyterlab-pygments 0.3.0
# Adding jupyterlab-pygments 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pygments==2.19.2
# Best match: pygments 2.19.2
# Adding pygments 2.19.2 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for mistune==0.8.4
# Best match: mistune 0.8.4
# Adding mistune 0.8.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for prompt-toolkit==3.0.51
# Best match: prompt-toolkit 3.0.51
# Adding prompt-toolkit 3.0.51 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for prometheus-client==0.22.1
# Best match: prometheus-client 0.22.1
# Adding prometheus-client 0.22.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for terminado==0.18.1
# Best match: terminado 0.18.1
# Adding terminado 0.18.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for Send2Trash==1.8.3
# Best match: Send2Trash 1.8.3
# Adding Send2Trash 1.8.3 to easy-install.pth file
# Installing send2trash script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Adding ipython-genutils 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for argon2-cffi==25.1.0
# Best match: argon2-cffi 25.1.0
# Adding argon2-cffi 25.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tcmlib==1.4.0
# Best match: tcmlib 1.4.0
# Adding tcmlib 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for intel-cmplr-lib-ur==2024.2.0
# Best match: intel-cmplr-lib-ur 2024.2.0
# Adding intel-cmplr-lib-ur 2024.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for notebook-shim==0.2.4
# Best match: notebook-shim 0.2.4
# Adding notebook-shim 0.2.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for ypy-websocket==0.8.4
# Best match: ypy-websocket 0.8.4
# Adding ypy-websocket 0.8.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-server-fileid==0.9.3
# Best match: jupyter-server-fileid 0.9.3
# Adding jupyter-server-fileid 0.9.3 to easy-install.pth file
# Installing jupyter-fileid script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for y-py==0.6.2
# Best match: y-py 0.6.2
# Adding y-py 0.6.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for websocket-client==1.8.0
# Best match: websocket-client 1.8.0
# Adding websocket-client 1.8.0 to easy-install.pth file
# Installing wsdump script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for overrides==7.7.0
# Best match: overrides 7.7.0
# Adding overrides 7.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-server-terminals==0.5.3
# Best match: jupyter-server-terminals 0.5.3
# Adding jupyter-server-terminals 0.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jupyter-events==0.12.0
# Best match: jupyter-events 0.12.0
# Adding jupyter-events 0.12.0 to easy-install.pth file
# Installing jupyter-events script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for anyio==4.11.0
# Best match: anyio 4.11.0
# Adding anyio 4.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for requests==2.32.5
# Best match: requests 2.32.5
# Adding requests 2.32.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jsonschema==4.25.0
# Best match: jsonschema 4.25.0
# Adding jsonschema 4.25.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for json5==0.12.1
# Best match: json5 0.12.1
# Adding json5 0.12.1 to easy-install.pth file
# Installing pyjson5 script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for babel==2.17.0
# Best match: babel 2.17.0
# Adding babel 2.17.0 to easy-install.pth file
# Installing pybabel script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for platformdirs==4.5.0
# Best match: platformdirs 4.5.0
# Adding platformdirs 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pexpect==4.9.0
# Best match: pexpect 4.9.0
# Adding pexpect 4.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for backcall==0.2.0
# Best match: backcall 0.2.0
# Adding backcall 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pickleshare==0.7.5
# Best match: pickleshare 0.7.5
# Adding pickleshare 0.7.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for decorator==4.4.2
# Best match: decorator 4.4.2
# Adding decorator 4.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jedi==0.19.2
# Best match: jedi 0.19.2
# Adding jedi 0.19.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for setuptools==75.2.0
# Best match: setuptools 75.2.0
# Adding setuptools 75.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for typing-extensions==4.15.0
# Best match: typing-extensions 4.15.0
# Adding typing-extensions 4.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for soupsieve==2.7
# Best match: soupsieve 2.7
# Adding soupsieve 2.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Adding webencodings 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for fastjsonschema==2.21.1
# Best match: fastjsonschema 2.21.1
# Adding fastjsonschema 2.21.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for wcwidth==0.2.13
# Best match: wcwidth 0.2.13
# Adding wcwidth 0.2.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for ptyprocess==0.7.0
# Best match: ptyprocess 0.7.0
# Adding ptyprocess 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for argon2-cffi-bindings==21.2.0
# Best match: argon2-cffi-bindings 21.2.0
# Adding argon2-cffi-bindings 21.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for aiosqlite==0.21.0
# Best match: aiosqlite 0.21.0
# Adding aiosqlite 0.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for aiofiles==22.1.0
# Best match: aiofiles 22.1.0
# Adding aiofiles 22.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for rfc3986-validator==0.1.1
# Best match: rfc3986-validator 0.1.1
# Adding rfc3986-validator 0.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for rfc3339-validator==0.1.4
# Best match: rfc3339-validator 0.1.4
# Adding rfc3339-validator 0.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for referencing==0.36.2
# Best match: referencing 0.36.2
# Adding referencing 0.36.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pyyaml==6.0.3
# Best match: pyyaml 6.0.3
# Adding pyyaml 6.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for python-json-logger==4.0.0
# Best match: python-json-logger 4.0.0
# Adding python-json-logger 4.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for sniffio==1.3.1
# Best match: sniffio 1.3.1
# Adding sniffio 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for idna==3.11
# Best match: idna 3.11
# Adding idna 3.11 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for certifi==2025.10.5
# Best match: certifi 2025.10.5
# Adding certifi 2025.10.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for urllib3==2.5.0
# Best match: urllib3 2.5.0
# Adding urllib3 2.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for charset-normalizer==3.4.4
# Best match: charset-normalizer 3.4.4
# Adding charset-normalizer 3.4.4 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for rpds-py==0.26.0
# Best match: rpds-py 0.26.0
# Adding rpds-py 0.26.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jsonschema-specifications==2025.4.1
# Best match: jsonschema-specifications 2025.4.1
# Adding jsonschema-specifications 2025.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for attrs==25.4.0
# Best match: attrs 25.4.0
# Adding attrs 25.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for parso==0.8.4
# Best match: parso 0.8.4
# Adding parso 0.8.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for cffi==2.0.0
# Best match: cffi 2.0.0
# Adding cffi 2.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for webcolors==24.11.1
# Best match: webcolors 24.11.1
# Adding webcolors 24.11.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for uri-template==1.3.0
# Best match: uri-template 1.3.0
# Adding uri-template 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for rfc3987-syntax==1.1.0
# Best match: rfc3987-syntax 1.1.0
# Adding rfc3987-syntax 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jsonpointer==3.0.0
# Best match: jsonpointer 3.0.0
# Adding jsonpointer 3.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for isoduration==20.11.0
# Best match: isoduration 20.11.0
# Adding isoduration 20.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for fqdn==1.5.1
# Best match: fqdn 1.5.1
# Adding fqdn 1.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pycparser==2.23
# Best match: pycparser 2.23
# Adding pycparser 2.23 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for lark==1.3.1
# Best match: lark 1.3.1
# Adding lark 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for arrow==1.4.0
# Best match: arrow 1.4.0
# Adding arrow 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tzdata==2025.2
# Best match: tzdata 2025.2
# Adding tzdata 2025.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for gprMax==3.1.6

# %%
# !python run_roots_cir.py
# Out:
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.6 (Big Smoke)
#
#  Copyright (C) 2015-2023: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: 12b0329eb996 | Google Google Compute Engine | 1 x Intel(R) Xeon(R) CPU @ 2.00GHz (2 cores, 4 cores with Hyper-Threading) | 31.4GiB RAM | Linux-6.6.56+-x86_64-with-glibc2.35
# GPU(s) detected: 0 - Tesla P100-PCIE-16GB, 15.9GiB
#
# --- Model 1/72, input file: circular_scan.in ----------------------------------
#
# Constants/variables used/available for Python scripting: {Coordinate: <class 'gprMax.input_cmd_funcs.Coordinate'>, Coordinate_tuple: <class 'gprMax.input_cmd_funcs.Coordinate'>, _: [[0.6   1.6  ]
#  [0.605 1.515]
#  [0.605 1.685]
#  [0.615 1.425]
#  [0.615 1.775]
#  [0.635 1.34 ]
#  [0.635 1.86 ]
#  [0.66  1.26 ]
#  [0.66  1.94 ]
#  [0.695 1.175]
#  [0.695 2.025]
#  [0.735 1.1  ]
#  [0.735 2.1  ]
#  [0.78  1.025]
#  [0.78  2.175]
#  [0.835 0.955]
#  [0.835 2.245]
#  [0.895 0.895]
#  [0.895 2.305]
#  [0.955 0.835]
#  [0.955 2.365]
#  [1.025 0.78 ]
#  [1.025 2.42 ]
#  [1.1   0.735]
#  [1.1   2.465]
#  [1.175 0.695]
#  [1.175 2.505]
#  [1.26  0.66 ]
#  [1.26  2.54 ]
#  [1.34  0.635]
#  [1.34  2.565]
#  [1.425 0.615]
#  [1.425 2.585]
#  [1.515 0.605]
#  [1.515 2.595]
#  [1.6   0.6  ]
#  [1.6   2.6  ]
#  [1.685 0.605]
#  [1.685 2.595]
#  [1.775 0.615]
#  [1.775 2.585]
#  [1.86  0.635]
#  [1.86  2.565]
#  [1.94  0.66 ]
#  [1.94  2.54 ]
#  [2.025 0.695]
#  [2.025 2.505]
#  [2.1   0.735]
#  [2.1   2.465]
#  [2.175 0.78 ]
#  [2.175 2.42 ]
#  [2.245 0.835]
#  [2.245 2.365]
#  [2.305 0.895]
#  [2.305 2.305]
#  [2.365 0.955]
#  [2.365 2.245]
#  [2.42  1.025]
#  [2.42  2.175]
#  [2.465 1.1  ]
#  [2.465 2.1  ]
#  [2.505 1.175]
#  [2.505 2.025]
#  [2.54  1.26 ]
#  [2.54  1.94 ]
#  [2.565 1.34 ]
#  [2.565 1.86 ]
#  [2.585 1.425]
#  [2.585 1.775]
#  [2.595 1.515]
#  [2.595 1.685]
#  [2.6   1.6  ]], angles: [ 0.          0.08522023  0.17583028  0.26318054  0.3470616   0.43904407
#   0.52411193  0.61154396  0.70049637  0.78539816  0.87029996  0.95925237
#   1.04668439  1.13175225  1.22373472  1.30761579  1.39496605  1.4855761
#   1.57079633  1.65601656  1.7466266   1.83397686  1.91785793  2.0098404
#   2.09490826  2.18234029  2.2712927   2.35619449  2.44109628  2.53004869
#   2.61748072  2.70254858  2.79453105  2.87841212  2.96576238  3.05637242
#   3.14159265 -3.05637242 -2.96576238 -2.87841212 -2.79453105 -2.70254858
#  -2.61748072 -2.53004869 -2.44109628 -2.35619449 -2.2712927  -2.18234029
#  -2.09490826 -2.0098404  -1.91785793 -1.83397686 -1.7466266  -1.65601656
#  -1.57079633 -1.4855761  -1.39496605 -1.30761579 -1.22373472 -1.13175225
#  -1.04668439 -0.95925237 -0.87029996 -0.78539816 -0.70049637 -0.61154396
#  -0.52411193 -0.43904407 -0.3470616  -0.26318054 -0.17583028 -0.08522023], box: <function box at 0x7b4fca42c5e0>, c: 299792458.0, command: <function command at 0x7b4fca5c3c40>, current_model_run: 1, cx: 1.6, cy: 1.6, cylinder: <function cylinder at 0x7b4fca42c720>, cylindrical_sector: <function cylindrical_sector at 0x7b4fca42c7c0>, delta: 0.005, domain: <function domain at 0x7b4fca42c040>, dx_dy_dz: <function dx_dy_dz at 0x7b4fca42c0e0>, e0: 8.8541878188e-12, edge: <function edge at 0x7b4fca42c400>, excitation_file: <function excitation_file at 0x7b4fca42c860>, geometry_objects_read: <function geometry_objects_read at 0x7b4fca42ce00>, geometry_view: <function geometry_view at 0x7b4fca42c2c0>, hertzian_dipole: <function hertzian_dipole at 0x7b4fca42c9a0>, idx: [36 37 35 38 34 39 33 40 32 41 31 42 30 43 29 44 28 45 27 46 26 47 25 48
#  24 49 23 50 22 51 21 52 20 53 19 54 18 55 17 56 16 57 15 58 14 59 13 60
#  12 61 11 62 10 63  9 64  8 65  7 66  6 67  5 68  4 69  3 70  2 71  1  0], inputfile: /kaggle/working/roots_3d/circular_scan.in, m0: 1.25663706127e-06, magnetic_dipole: <function magnetic_dipole at 0x7b4fca42ca40>, material: <function material at 0x7b4fca42c220>, namedtuple: <function namedtuple at 0x7b4fecf59080>, np: <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>, number_model_runs: 72, plate: <function plate at 0x7b4fca42c4a0>, points: [[0.605 1.515]
#  [0.615 1.425]
#  [0.635 1.34 ]
#  [0.66  1.26 ]
#  [0.695 1.175]
#  [0.735 1.1  ]
#  [0.78  1.025]
#  [0.835 0.955]
#  [0.895 0.895]
#  [0.955 0.835]
#  [1.025 0.78 ]
#  [1.1   0.735]
#  [1.175 0.695]
#  [1.26  0.66 ]
#  [1.34  0.635]
#  [1.425 0.615]
#  [1.515 0.605]
#  [1.6   0.6  ]
#  [1.685 0.605]
#  [1.775 0.615]
#  [1.86  0.635]
#  [1.94  0.66 ]
#  [2.025 0.695]
#  [2.1   0.735]
#  [2.175 0.78 ]
#  [2.245 0.835]
#  [2.305 0.895]
#  [2.365 0.955]
#  [2.42  1.025]
#  [2.465 1.1  ]
#  [2.505 1.175]
#  [2.54  1.26 ]
#  [2.565 1.34 ]
#  [2.585 1.425]
#  [2.595 1.515]
#  [2.6   1.6  ]
#  [2.595 1.685]
#  [2.585 1.775]
#  [2.565 1.86 ]
#  [2.54  1.94 ]
#  [2.505 2.025]
#  [2.465 2.1  ]
#  [2.42  2.175]
#  [2.365 2.245]
#  [2.305 2.305]
#  [2.245 2.365]
#  [2.175 2.42 ]
#  [2.1   2.465]
#  [2.025 2.505]
#  [1.94  2.54 ]
#  [1.86  2.565]
#  [1.775 2.585]
#  [1.685 2.595]
#  [1.6   2.6  ]
#  [1.515 2.595]
#  [1.425 2.585]
#  [1.34  2.565]
#  [1.26  2.54 ]
#  [1.175 2.505]
#  [1.1   2.465]
#  [1.025 2.42 ]
#  [0.955 2.365]
#  [0.895 2.305]
#  [0.835 2.245]
#  [0.78  2.175]
#  [0.735 2.1  ]
#  [0.695 2.025]
#  [0.66  1.94 ]
#  [0.635 1.86 ]
#  [0.615 1.775]
#  [0.605 1.685]
#  [0.6   1.6  ]], r: 1, rotate90_edge: <function rotate90_edge at 0x7b4fca5c3ec0>, rotate90_plate: <function rotate90_plate at 0x7b4fca5c3f60>, rotate90_point: <function rotate90_point at 0x7b4fca5c3e20>, rx: <function rx at 0x7b4fca42cc20>, rx_steps: <function rx_steps at 0x7b4fca42cd60>, snapshot: <function snapshot at 0x7b4fca42c360>, sphere: <function sphere at 0x7b4fca42c680>, src_steps: <function src_steps at 0x7b4fca42ccc0>, sys: <module 'sys' (built-in)>, theta: [0.         0.08726646 0.17453293 0.26179939 0.34906585 0.43633231
#  0.52359878 0.61086524 0.6981317  0.78539816 0.87266463 0.95993109
#  1.04719755 1.13446401 1.22173048 1.30899694 1.3962634  1.48352986
#  1.57079633 1.65806279 1.74532925 1.83259571 1.91986218 2.00712864
#  2.0943951  2.18166156 2.26892803 2.35619449 2.44346095 2.53072742
#  2.61799388 2.70526034 2.7925268  2.87979327 2.96705973 3.05432619
#  3.14159265 3.22885912 3.31612558 3.40339204 3.4906585  3.57792497
#  3.66519143 3.75245789 3.83972435 3.92699082 4.01425728 4.10152374
#  4.1887902  4.27605667 4.36332313 4.45058959 4.53785606 4.62512252
#  4.71238898 4.79965544 4.88692191 4.97418837 5.06145483 5.14872129
#  5.23598776 5.32325422 5.41052068 5.49778714 5.58505361 5.67232007
#  5.75958653 5.84685299 5.93411946 6.02138592 6.10865238 6.19591884
#  6.28318531], time_window: <function time_window at 0x7b4fca42c180>, transmission_line: <function transmission_line at 0x7b4fca42cb80>, triangle: <function triangle at 0x7b4fca42c540>, voltage_source: <function voltage_source at 0x7b4fca42cae0>, waveform: <function waveform at 0x7b4fca42c900>, x: [2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6       ], xq: [2.6   2.595 2.585 2.565 2.54  2.505 2.465 2.42  2.365 2.305 2.245 2.175
#  2.1   2.025 1.94  1.86  1.775 1.685 1.6   1.515 1.425 1.34  1.26  1.175
#  1.1   1.025 0.955 0.895 0.835 0.78  0.735 0.695 0.66  0.635 0.615 0.605
#  0.6   0.605 0.615 0.635 0.66  0.695 0.735 0.78  0.835 0.895 0.955 1.025
#  1.1   1.175 1.26  1.34  1.425 1.515 1.6   1.685 1.775 1.86  1.94  2.025
#  2.1   2.175 2.245 2.305 2.365 2.42  2.465 2.505 2.54  2.565 2.585 2.595
#  2.6  ], y: [1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6       ], yq: [1.6   1.685 1.775 1.86  1.94  2.025 2.1   2.175 2.245 2.305 2.365 2.42
#  2.465 2.505 2.54  2.565 2.585 2.595 2.6   2.595 2.585 2.565 2.54  2.505
#  2.465 2.42  2.365 2.305 2.245 2.175 2.1   2.025 1.94  1.86  1.775 1.685
#  1.6   1.515 1.425 1.34  1.26  1.175 1.1   1.025 0.955 0.895 0.835 0.78
#  0.735 0.695 0.66  0.635 0.615 0.605 0.6   0.605 0.615 0.635 0.66  0.695
#  0.735 0.78  0.835 0.895 0.955 1.025 1.1   1.175 1.26  1.34  1.425 1.515
#  1.6  ], z0: 376.7303134118051}
#
# Model title: Roots under Hete Soil Imaging
# Number of CPU (OpenMP) threads: 2
# GPU solving using: 0 - Tesla P100-PCIE-16GB
# Spatial discretisation: 0.005 x 0.005 x 0.005m
# Domain size: 3.2 x 1.7 x 3.2m (640 x 340 x 640 = 1.39264e+08 cells)
# Mode: 3D
# Time step (at CFL limit): 9.62917e-12 secs
# Time window: 3e-08 secs (3117 iterations)
#
# Waveform my_gaussian of type gaussian with maximum amplitude scaling 1, frequency 5e+08Hz created.
# Hertzian dipole with polarity y at 0.605m, 1.25m, 1.515m, using waveform my_gaussian created.
# Receiver at 0.6m, 1.25m, 1.6m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material confined_material with eps_r=5.24, sigma=0.001 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Mixing model (Peplinski) used to create hete_soil with sand fraction 0.3, clay fraction 0.7, bulk density 2g/cm3, sand particle density 2.66g/cm3, and water volumetric fraction 0.01 to 0.15 created.
#
# Memory (RAM) required: ~9.96GB host + ~9.96GB GPU
#
# Fractal box my_fractal_box from 0.1m, 0.1m, 0.1m, to 3.1m, 1m, 3.1m with hete_soil, fractal dimension 1.5, fractal weightings 1, 1, 1, fractal seeding 42, with 20 material(s) created, dielectric smoothing is off.
# Box from 0.1m, 1m, 0.1m, to 3.1m, 1.15m, 3.1m of material(s) confined_material created, dielectric smoothing is on.
# Material Object0{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Object1{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry objects from file (voxels only) test.h5 inserted at 0.6m, 0.1m, 0.6m, with corresponding materials file Object_materials.txt.
# Processing geometry related cmds: 100%|████████| 3/3 [00:21<00:00,  7.06s/cmds]
#
# PML: formulation: HORIPML, order: 1, thickness: 20
# Building PML boundaries: 100%|███████████████████| 6/6 [00:06<00:00,  1.03s/it]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:30<00:00, 15.17s/it]
#
# Memory (RAM) required - updated (dispersive): ~13.3GB
#
#
# Materials:
#     |                                                    |                     |         | sigma     | Delta     | tau       | omega | delta | gamma |      | sigma*  | Dielectric
#  ID | Name                                               | Type                | eps_r   | [S/m]     | eps_r     | [s]       | [Hz]  | [Hz]  | [Hz]  | mu_r | [Ohm/m] | smoothable
# ----+----------------------------------------------------+---------------------+---------+-----------+-----------+-----------+-------+-------+-------+------+---------+------------
#   0 | pec                                                | builtin             | 1       | inf       |           |           |       |       |       | 1    | 0       | False
#   1 | free_space                                         | builtin             | 1       | 0         |           |           |       |       |       | 1    | 0       | True
#   2 | confined_material                                  |                     | 5.24    | 0.001     |           |           |       |       |       | 1    | 0       | True
#   3 | |0.0137|                                           | debye               | 3.98341 | 0.0155417 | 0.0779246 | 9.231e-12 |       |       |       | 1    | 0       | False
#   4 | |0.0211|                                           | debye               | 4.243   | 0.0201373 | 0.155333  | 9.231e-12 |       |       |       | 1    | 0       | False
#   5 | |0.0284|                                           | debye               | 4.49387 | 0.02412   | 0.251173  | 9.231e-12 |       |       |       | 1    | 0       | False
#   6 | |0.0358|                                           | debye               | 4.73764 | 0.0277064 | 0.363321  | 9.231e-12 |       |       |       | 1    | 0       | False
#   7 | |0.0432|                                           | debye               | 4.97542 | 0.0310078 | 0.490329  | 9.231e-12 |       |       |       | 1    | 0       | False
#   8 | |0.0505|                                           | debye               | 5.20804 | 0.0340908 | 0.631118  | 9.231e-12 |       |       |       | 1    | 0       | False
#   9 | |0.0579|                                           | debye               | 5.43612 | 0.036999  | 0.784846  | 9.231e-12 |       |       |       | 1    | 0       | False
#  10 | |0.0653|                                           | debye               | 5.66017 | 0.0397628 | 0.950824  | 9.231e-12 |       |       |       | 1    | 0       | False
#  11 | |0.0726|                                           | debye               | 5.88059 | 0.0424046 | 1.12848   | 9.231e-12 |       |       |       | 1    | 0       | False
#  12 | |0.0800|                                           | debye               | 6.09774 | 0.0449416 | 1.31733   | 9.231e-12 |       |       |       | 1    | 0       | False
#  13 | |0.0874|                                           | debye               | 6.3119  | 0.0473869 | 1.51694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  14 | |0.0947|                                           | debye               | 6.52331 | 0.0497512 | 1.72694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  15 | |0.1021|                                           | debye               | 6.7322  | 0.0520433 | 1.94701   | 9.231e-12 |       |       |       | 1    | 0       | False
#  16 | |0.1095|                                           | debye               | 6.93874 | 0.0542703 | 2.17685   | 9.231e-12 |       |       |       | 1    | 0       | False
#  17 | |0.1168|                                           | debye               | 7.1431  | 0.0564383 | 2.41618   | 9.231e-12 |       |       |       | 1    | 0       | False
#  18 | |0.1242|                                           | debye               | 7.34543 | 0.0585524 | 2.66476   | 9.231e-12 |       |       |       | 1    | 0       | False
#  19 | |0.1316|                                           | debye               | 7.54585 | 0.0606171 | 2.92238   | 9.231e-12 |       |       |       | 1    | 0       | False
#  20 | |0.1389|                                           | debye               | 7.74449 | 0.0626362 | 3.18883   | 9.231e-12 |       |       |       | 1    | 0       | False
#  21 | |0.1463|                                           | debye               | 7.94144 | 0.064613  | 3.46391   | 9.231e-12 |       |       |       | 1    | 0       | False
#  22 | |0.1537|                                           | debye               | 8.1368  | 0.0665505 | 3.74745   | 9.231e-12 |       |       |       | 1    | 0       | False
#  23 | Object0{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  24 | Object1{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  25 | confined_material+confined_material+free_space+fre | dielectric-smoothed | 3.12    | 0.0005    |           |           |       |       |       | 1    | 0       | True
#  26 | free_space+confined_material+free_space+free_space | dielectric-smoothed | 2.06    | 0.00025   |           |           |       |       |       | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -1.81% in material 'Object0{Object_materials}' whose wavelength sampled by 7 cells. Maximum significant frequency estimated as 1.53261e+09Hz
#
# Output file: /kaggle/working/roots_3d/circular_scan1.out
#
# Running simulation, model 1/72: 100%|██████| 3117/3117 [04:08<00:00, 12.55it/s]
# Memory (RAM) used: ~6GB host + ~11GB GPU
# Solving time [HH:MM:SS]: 0:04:13.316969
#
# --- Model 2/72, input file: circular_scan.in ----------------------------------
#
# Constants/variables used/available for Python scripting: {Coordinate: <class 'gprMax.input_cmd_funcs.Coordinate'>, Coordinate_tuple: <class 'gprMax.input_cmd_funcs.Coordinate'>, _: [[0.6   1.6  ]
#  [0.605 1.515]
#  [0.605 1.685]
#  [0.615 1.425]
#  [0.615 1.775]
#  [0.635 1.34 ]
#  [0.635 1.86 ]
#  [0.66  1.26 ]
#  [0.66  1.94 ]
#  [0.695 1.175]
#  [0.695 2.025]
#  [0.735 1.1  ]
#  [0.735 2.1  ]
#  [0.78  1.025]
#  [0.78  2.175]
#  [0.835 0.955]
#  [0.835 2.245]
#  [0.895 0.895]
#  [0.895 2.305]
#  [0.955 0.835]
#  [0.955 2.365]
#  [1.025 0.78 ]
#  [1.025 2.42 ]
#  [1.1   0.735]
#  [1.1   2.465]
#  [1.175 0.695]
#  [1.175 2.505]
#  [1.26  0.66 ]
#  [1.26  2.54 ]
#  [1.34  0.635]
#  [1.34  2.565]
#  [1.425 0.615]
#  [1.425 2.585]
#  [1.515 0.605]
#  [1.515 2.595]
#  [1.6   0.6  ]
#  [1.6   2.6  ]
#  [1.685 0.605]
#  [1.685 2.595]
#  [1.775 0.615]
#  [1.775 2.585]
#  [1.86  0.635]
#  [1.86  2.565]
#  [1.94  0.66 ]
#  [1.94  2.54 ]
#  [2.025 0.695]
#  [2.025 2.505]
#  [2.1   0.735]
#  [2.1   2.465]
#  [2.175 0.78 ]
#  [2.175 2.42 ]
#  [2.245 0.835]
#  [2.245 2.365]
#  [2.305 0.895]
#  [2.305 2.305]
#  [2.365 0.955]
#  [2.365 2.245]
#  [2.42  1.025]
#  [2.42  2.175]
#  [2.465 1.1  ]
#  [2.465 2.1  ]
#  [2.505 1.175]
#  [2.505 2.025]
#  [2.54  1.26 ]
#  [2.54  1.94 ]
#  [2.565 1.34 ]
#  [2.565 1.86 ]
#  [2.585 1.425]
#  [2.585 1.775]
#  [2.595 1.515]
#  [2.595 1.685]
#  [2.6   1.6  ]], angles: [ 0.          0.08522023  0.17583028  0.26318054  0.3470616   0.43904407
#   0.52411193  0.61154396  0.70049637  0.78539816  0.87029996  0.95925237
#   1.04668439  1.13175225  1.22373472  1.30761579  1.39496605  1.4855761
#   1.57079633  1.65601656  1.7466266   1.83397686  1.91785793  2.0098404
#   2.09490826  2.18234029  2.2712927   2.35619449  2.44109628  2.53004869
#   2.61748072  2.70254858  2.79453105  2.87841212  2.96576238  3.05637242
#   3.14159265 -3.05637242 -2.96576238 -2.87841212 -2.79453105 -2.70254858
#  -2.61748072 -2.53004869 -2.44109628 -2.35619449 -2.2712927  -2.18234029
#  -2.09490826 -2.0098404  -1.91785793 -1.83397686 -1.7466266  -1.65601656
#  -1.57079633 -1.4855761  -1.39496605 -1.30761579 -1.22373472 -1.13175225
#  -1.04668439 -0.95925237 -0.87029996 -0.78539816 -0.70049637 -0.61154396
#  -0.52411193 -0.43904407 -0.3470616  -0.26318054 -0.17583028 -0.08522023], box: <function box at 0x7b4fca42c5e0>, c: 299792458.0, command: <function command at 0x7b4fca5c3c40>, current_model_run: 2, cx: 1.6, cy: 1.6, cylinder: <function cylinder at 0x7b4fca42c720>, cylindrical_sector: <function cylindrical_sector at 0x7b4fca42c7c0>, delta: 0.005, domain: <function domain at 0x7b4fca42c040>, dx_dy_dz: <function dx_dy_dz at 0x7b4fca42c0e0>, e0: 8.8541878188e-12, edge: <function edge at 0x7b4fca42c400>, excitation_file: <function excitation_file at 0x7b4fca42c860>, geometry_objects_read: <function geometry_objects_read at 0x7b4fca42ce00>, geometry_view: <function geometry_view at 0x7b4fca42c2c0>, hertzian_dipole: <function hertzian_dipole at 0x7b4fca42c9a0>, idx: [36 37 35 38 34 39 33 40 32 41 31 42 30 43 29 44 28 45 27 46 26 47 25 48
#  24 49 23 50 22 51 21 52 20 53 19 54 18 55 17 56 16 57 15 58 14 59 13 60
#  12 61 11 62 10 63  9 64  8 65  7 66  6 67  5 68  4 69  3 70  2 71  1  0], inputfile: /kaggle/working/roots_3d/circular_scan.in, m0: 1.25663706127e-06, magnetic_dipole: <function magnetic_dipole at 0x7b4fca42ca40>, material: <function material at 0x7b4fca42c220>, namedtuple: <function namedtuple at 0x7b4fecf59080>, np: <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>, number_model_runs: 72, plate: <function plate at 0x7b4fca42c4a0>, points: [[0.605 1.515]
#  [0.615 1.425]
#  [0.635 1.34 ]
#  [0.66  1.26 ]
#  [0.695 1.175]
#  [0.735 1.1  ]
#  [0.78  1.025]
#  [0.835 0.955]
#  [0.895 0.895]
#  [0.955 0.835]
#  [1.025 0.78 ]
#  [1.1   0.735]
#  [1.175 0.695]
#  [1.26  0.66 ]
#  [1.34  0.635]
#  [1.425 0.615]
#  [1.515 0.605]
#  [1.6   0.6  ]
#  [1.685 0.605]
#  [1.775 0.615]
#  [1.86  0.635]
#  [1.94  0.66 ]
#  [2.025 0.695]
#  [2.1   0.735]
#  [2.175 0.78 ]
#  [2.245 0.835]
#  [2.305 0.895]
#  [2.365 0.955]
#  [2.42  1.025]
#  [2.465 1.1  ]
#  [2.505 1.175]
#  [2.54  1.26 ]
#  [2.565 1.34 ]
#  [2.585 1.425]
#  [2.595 1.515]
#  [2.6   1.6  ]
#  [2.595 1.685]
#  [2.585 1.775]
#  [2.565 1.86 ]
#  [2.54  1.94 ]
#  [2.505 2.025]
#  [2.465 2.1  ]
#  [2.42  2.175]
#  [2.365 2.245]
#  [2.305 2.305]
#  [2.245 2.365]
#  [2.175 2.42 ]
#  [2.1   2.465]
#  [2.025 2.505]
#  [1.94  2.54 ]
#  [1.86  2.565]
#  [1.775 2.585]
#  [1.685 2.595]
#  [1.6   2.6  ]
#  [1.515 2.595]
#  [1.425 2.585]
#  [1.34  2.565]
#  [1.26  2.54 ]
#  [1.175 2.505]
#  [1.1   2.465]
#  [1.025 2.42 ]
#  [0.955 2.365]
#  [0.895 2.305]
#  [0.835 2.245]
#  [0.78  2.175]
#  [0.735 2.1  ]
#  [0.695 2.025]
#  [0.66  1.94 ]
#  [0.635 1.86 ]
#  [0.615 1.775]
#  [0.605 1.685]
#  [0.6   1.6  ]], r: 1, rotate90_edge: <function rotate90_edge at 0x7b4fca5c3ec0>, rotate90_plate: <function rotate90_plate at 0x7b4fca5c3f60>, rotate90_point: <function rotate90_point at 0x7b4fca5c3e20>, rx: <function rx at 0x7b4fca42cc20>, rx_steps: <function rx_steps at 0x7b4fca42cd60>, snapshot: <function snapshot at 0x7b4fca42c360>, sphere: <function sphere at 0x7b4fca42c680>, src_steps: <function src_steps at 0x7b4fca42ccc0>, sys: <module 'sys' (built-in)>, theta: [0.         0.08726646 0.17453293 0.26179939 0.34906585 0.43633231
#  0.52359878 0.61086524 0.6981317  0.78539816 0.87266463 0.95993109
#  1.04719755 1.13446401 1.22173048 1.30899694 1.3962634  1.48352986
#  1.57079633 1.65806279 1.74532925 1.83259571 1.91986218 2.00712864
#  2.0943951  2.18166156 2.26892803 2.35619449 2.44346095 2.53072742
#  2.61799388 2.70526034 2.7925268  2.87979327 2.96705973 3.05432619
#  3.14159265 3.22885912 3.31612558 3.40339204 3.4906585  3.57792497
#  3.66519143 3.75245789 3.83972435 3.92699082 4.01425728 4.10152374
#  4.1887902  4.27605667 4.36332313 4.45058959 4.53785606 4.62512252
#  4.71238898 4.79965544 4.88692191 4.97418837 5.06145483 5.14872129
#  5.23598776 5.32325422 5.41052068 5.49778714 5.58505361 5.67232007
#  5.75958653 5.84685299 5.93411946 6.02138592 6.10865238 6.19591884
#  6.28318531], time_window: <function time_window at 0x7b4fca42c180>, transmission_line: <function transmission_line at 0x7b4fca42cb80>, triangle: <function triangle at 0x7b4fca42c540>, voltage_source: <function voltage_source at 0x7b4fca42cae0>, waveform: <function waveform at 0x7b4fca42c900>, x: [2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6       ], xq: [2.6   2.595 2.585 2.565 2.54  2.505 2.465 2.42  2.365 2.305 2.245 2.175
#  2.1   2.025 1.94  1.86  1.775 1.685 1.6   1.515 1.425 1.34  1.26  1.175
#  1.1   1.025 0.955 0.895 0.835 0.78  0.735 0.695 0.66  0.635 0.615 0.605
#  0.6   0.605 0.615 0.635 0.66  0.695 0.735 0.78  0.835 0.895 0.955 1.025
#  1.1   1.175 1.26  1.34  1.425 1.515 1.6   1.685 1.775 1.86  1.94  2.025
#  2.1   2.175 2.245 2.305 2.365 2.42  2.465 2.505 2.54  2.565 2.585 2.595
#  2.6  ], y: [1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6       ], yq: [1.6   1.685 1.775 1.86  1.94  2.025 2.1   2.175 2.245 2.305 2.365 2.42
#  2.465 2.505 2.54  2.565 2.585 2.595 2.6   2.595 2.585 2.565 2.54  2.505
#  2.465 2.42  2.365 2.305 2.245 2.175 2.1   2.025 1.94  1.86  1.775 1.685
#  1.6   1.515 1.425 1.34  1.26  1.175 1.1   1.025 0.955 0.895 0.835 0.78
#  0.735 0.695 0.66  0.635 0.615 0.605 0.6   0.605 0.615 0.635 0.66  0.695
#  0.735 0.78  0.835 0.895 0.955 1.025 1.1   1.175 1.26  1.34  1.425 1.515
#  1.6  ], z0: 376.7303134118051}
#
# Model title: Roots under Hete Soil Imaging
# Number of CPU (OpenMP) threads: 2
# GPU solving using: 0 - Tesla P100-PCIE-16GB
# Spatial discretisation: 0.005 x 0.005 x 0.005m
# Domain size: 3.2 x 1.7 x 3.2m (640 x 340 x 640 = 1.39264e+08 cells)
# Mode: 3D
# Time step (at CFL limit): 9.62917e-12 secs
# Time window: 3e-08 secs (3117 iterations)
#
# Waveform my_gaussian of type gaussian with maximum amplitude scaling 1, frequency 5e+08Hz created.
# Hertzian dipole with polarity y at 0.615m, 1.25m, 1.425m, using waveform my_gaussian created.
# Receiver at 0.605m, 1.25m, 1.515m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material confined_material with eps_r=5.24, sigma=0.001 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Mixing model (Peplinski) used to create hete_soil with sand fraction 0.3, clay fraction 0.7, bulk density 2g/cm3, sand particle density 2.66g/cm3, and water volumetric fraction 0.01 to 0.15 created.
#
# Memory (RAM) required: ~9.96GB host + ~9.96GB GPU
#
# Fractal box my_fractal_box from 0.1m, 0.1m, 0.1m, to 3.1m, 1m, 3.1m with hete_soil, fractal dimension 1.5, fractal weightings 1, 1, 1, fractal seeding 42, with 20 material(s) created, dielectric smoothing is off.
# Box from 0.1m, 1m, 0.1m, to 3.1m, 1.15m, 3.1m of material(s) confined_material created, dielectric smoothing is on.
# Material Object0{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Object1{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry objects from file (voxels only) test.h5 inserted at 0.6m, 0.1m, 0.6m, with corresponding materials file Object_materials.txt.
# Processing geometry related cmds: 100%|████████| 3/3 [00:21<00:00,  7.06s/cmds]
#
# PML: formulation: HORIPML, order: 1, thickness: 20
# Building PML boundaries: 100%|███████████████████| 6/6 [00:06<00:00,  1.03s/it]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:30<00:00, 15.08s/it]
#
# Memory (RAM) required - updated (dispersive): ~13.3GB
#
#
# Materials:
#     |                                                    |                     |         | sigma     | Delta     | tau       | omega | delta | gamma |      | sigma*  | Dielectric
#  ID | Name                                               | Type                | eps_r   | [S/m]     | eps_r     | [s]       | [Hz]  | [Hz]  | [Hz]  | mu_r | [Ohm/m] | smoothable
# ----+----------------------------------------------------+---------------------+---------+-----------+-----------+-----------+-------+-------+-------+------+---------+------------
#   0 | pec                                                | builtin             | 1       | inf       |           |           |       |       |       | 1    | 0       | False
#   1 | free_space                                         | builtin             | 1       | 0         |           |           |       |       |       | 1    | 0       | True
#   2 | confined_material                                  |                     | 5.24    | 0.001     |           |           |       |       |       | 1    | 0       | True
#   3 | |0.0137|                                           | debye               | 3.98341 | 0.0155417 | 0.0779246 | 9.231e-12 |       |       |       | 1    | 0       | False
#   4 | |0.0211|                                           | debye               | 4.243   | 0.0201373 | 0.155333  | 9.231e-12 |       |       |       | 1    | 0       | False
#   5 | |0.0284|                                           | debye               | 4.49387 | 0.02412   | 0.251173  | 9.231e-12 |       |       |       | 1    | 0       | False
#   6 | |0.0358|                                           | debye               | 4.73764 | 0.0277064 | 0.363321  | 9.231e-12 |       |       |       | 1    | 0       | False
#   7 | |0.0432|                                           | debye               | 4.97542 | 0.0310078 | 0.490329  | 9.231e-12 |       |       |       | 1    | 0       | False
#   8 | |0.0505|                                           | debye               | 5.20804 | 0.0340908 | 0.631118  | 9.231e-12 |       |       |       | 1    | 0       | False
#   9 | |0.0579|                                           | debye               | 5.43612 | 0.036999  | 0.784846  | 9.231e-12 |       |       |       | 1    | 0       | False
#  10 | |0.0653|                                           | debye               | 5.66017 | 0.0397628 | 0.950824  | 9.231e-12 |       |       |       | 1    | 0       | False
#  11 | |0.0726|                                           | debye               | 5.88059 | 0.0424046 | 1.12848   | 9.231e-12 |       |       |       | 1    | 0       | False
#  12 | |0.0800|                                           | debye               | 6.09774 | 0.0449416 | 1.31733   | 9.231e-12 |       |       |       | 1    | 0       | False
#  13 | |0.0874|                                           | debye               | 6.3119  | 0.0473869 | 1.51694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  14 | |0.0947|                                           | debye               | 6.52331 | 0.0497512 | 1.72694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  15 | |0.1021|                                           | debye               | 6.7322  | 0.0520433 | 1.94701   | 9.231e-12 |       |       |       | 1    | 0       | False
#  16 | |0.1095|                                           | debye               | 6.93874 | 0.0542703 | 2.17685   | 9.231e-12 |       |       |       | 1    | 0       | False
#  17 | |0.1168|                                           | debye               | 7.1431  | 0.0564383 | 2.41618   | 9.231e-12 |       |       |       | 1    | 0       | False
#  18 | |0.1242|                                           | debye               | 7.34543 | 0.0585524 | 2.66476   | 9.231e-12 |       |       |       | 1    | 0       | False
#  19 | |0.1316|                                           | debye               | 7.54585 | 0.0606171 | 2.92238   | 9.231e-12 |       |       |       | 1    | 0       | False
#  20 | |0.1389|                                           | debye               | 7.74449 | 0.0626362 | 3.18883   | 9.231e-12 |       |       |       | 1    | 0       | False
#  21 | |0.1463|                                           | debye               | 7.94144 | 0.064613  | 3.46391   | 9.231e-12 |       |       |       | 1    | 0       | False
#  22 | |0.1537|                                           | debye               | 8.1368  | 0.0665505 | 3.74745   | 9.231e-12 |       |       |       | 1    | 0       | False
#  23 | Object0{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  24 | Object1{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  25 | confined_material+confined_material+free_space+fre | dielectric-smoothed | 3.12    | 0.0005    |           |           |       |       |       | 1    | 0       | True
#  26 | free_space+confined_material+free_space+free_space | dielectric-smoothed | 2.06    | 0.00025   |           |           |       |       |       | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -1.81% in material 'Object0{Object_materials}' whose wavelength sampled by 7 cells. Maximum significant frequency estimated as 1.53261e+09Hz
#
# Output file: /kaggle/working/roots_3d/circular_scan2.out
#
# Running simulation, model 2/72: 100%|██████| 3117/3117 [04:08<00:00, 12.55it/s]
# Memory (RAM) used: ~6GB host + ~11GB GPU
# Solving time [HH:MM:SS]: 0:04:13.302594
#
# --- Model 3/72, input file: circular_scan.in ----------------------------------
#
# Constants/variables used/available for Python scripting: {Coordinate: <class 'gprMax.input_cmd_funcs.Coordinate'>, Coordinate_tuple: <class 'gprMax.input_cmd_funcs.Coordinate'>, _: [[0.6   1.6  ]
#  [0.605 1.515]
#  [0.605 1.685]
#  [0.615 1.425]
#  [0.615 1.775]
#  [0.635 1.34 ]
#  [0.635 1.86 ]
#  [0.66  1.26 ]
#  [0.66  1.94 ]
#  [0.695 1.175]
#  [0.695 2.025]
#  [0.735 1.1  ]
#  [0.735 2.1  ]
#  [0.78  1.025]
#  [0.78  2.175]
#  [0.835 0.955]
#  [0.835 2.245]
#  [0.895 0.895]
#  [0.895 2.305]
#  [0.955 0.835]
#  [0.955 2.365]
#  [1.025 0.78 ]
#  [1.025 2.42 ]
#  [1.1   0.735]
#  [1.1   2.465]
#  [1.175 0.695]
#  [1.175 2.505]
#  [1.26  0.66 ]
#  [1.26  2.54 ]
#  [1.34  0.635]
#  [1.34  2.565]
#  [1.425 0.615]
#  [1.425 2.585]
#  [1.515 0.605]
#  [1.515 2.595]
#  [1.6   0.6  ]
#  [1.6   2.6  ]
#  [1.685 0.605]
#  [1.685 2.595]
#  [1.775 0.615]
#  [1.775 2.585]
#  [1.86  0.635]
#  [1.86  2.565]
#  [1.94  0.66 ]
#  [1.94  2.54 ]
#  [2.025 0.695]
#  [2.025 2.505]
#  [2.1   0.735]
#  [2.1   2.465]
#  [2.175 0.78 ]
#  [2.175 2.42 ]
#  [2.245 0.835]
#  [2.245 2.365]
#  [2.305 0.895]
#  [2.305 2.305]
#  [2.365 0.955]
#  [2.365 2.245]
#  [2.42  1.025]
#  [2.42  2.175]
#  [2.465 1.1  ]
#  [2.465 2.1  ]
#  [2.505 1.175]
#  [2.505 2.025]
#  [2.54  1.26 ]
#  [2.54  1.94 ]
#  [2.565 1.34 ]
#  [2.565 1.86 ]
#  [2.585 1.425]
#  [2.585 1.775]
#  [2.595 1.515]
#  [2.595 1.685]
#  [2.6   1.6  ]], angles: [ 0.          0.08522023  0.17583028  0.26318054  0.3470616   0.43904407
#   0.52411193  0.61154396  0.70049637  0.78539816  0.87029996  0.95925237
#   1.04668439  1.13175225  1.22373472  1.30761579  1.39496605  1.4855761
#   1.57079633  1.65601656  1.7466266   1.83397686  1.91785793  2.0098404
#   2.09490826  2.18234029  2.2712927   2.35619449  2.44109628  2.53004869
#   2.61748072  2.70254858  2.79453105  2.87841212  2.96576238  3.05637242
#   3.14159265 -3.05637242 -2.96576238 -2.87841212 -2.79453105 -2.70254858
#  -2.61748072 -2.53004869 -2.44109628 -2.35619449 -2.2712927  -2.18234029
#  -2.09490826 -2.0098404  -1.91785793 -1.83397686 -1.7466266  -1.65601656
#  -1.57079633 -1.4855761  -1.39496605 -1.30761579 -1.22373472 -1.13175225
#  -1.04668439 -0.95925237 -0.87029996 -0.78539816 -0.70049637 -0.61154396
#  -0.52411193 -0.43904407 -0.3470616  -0.26318054 -0.17583028 -0.08522023], box: <function box at 0x7b4fca42c5e0>, c: 299792458.0, command: <function command at 0x7b4fca5c3c40>, current_model_run: 3, cx: 1.6, cy: 1.6, cylinder: <function cylinder at 0x7b4fca42c720>, cylindrical_sector: <function cylindrical_sector at 0x7b4fca42c7c0>, delta: 0.005, domain: <function domain at 0x7b4fca42c040>, dx_dy_dz: <function dx_dy_dz at 0x7b4fca42c0e0>, e0: 8.8541878188e-12, edge: <function edge at 0x7b4fca42c400>, excitation_file: <function excitation_file at 0x7b4fca42c860>, geometry_objects_read: <function geometry_objects_read at 0x7b4fca42ce00>, geometry_view: <function geometry_view at 0x7b4fca42c2c0>, hertzian_dipole: <function hertzian_dipole at 0x7b4fca42c9a0>, idx: [36 37 35 38 34 39 33 40 32 41 31 42 30 43 29 44 28 45 27 46 26 47 25 48
#  24 49 23 50 22 51 21 52 20 53 19 54 18 55 17 56 16 57 15 58 14 59 13 60
#  12 61 11 62 10 63  9 64  8 65  7 66  6 67  5 68  4 69  3 70  2 71  1  0], inputfile: /kaggle/working/roots_3d/circular_scan.in, m0: 1.25663706127e-06, magnetic_dipole: <function magnetic_dipole at 0x7b4fca42ca40>, material: <function material at 0x7b4fca42c220>, namedtuple: <function namedtuple at 0x7b4fecf59080>, np: <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>, number_model_runs: 72, plate: <function plate at 0x7b4fca42c4a0>, points: [[0.605 1.515]
#  [0.615 1.425]
#  [0.635 1.34 ]
#  [0.66  1.26 ]
#  [0.695 1.175]
#  [0.735 1.1  ]
#  [0.78  1.025]
#  [0.835 0.955]
#  [0.895 0.895]
#  [0.955 0.835]
#  [1.025 0.78 ]
#  [1.1   0.735]
#  [1.175 0.695]
#  [1.26  0.66 ]
#  [1.34  0.635]
#  [1.425 0.615]
#  [1.515 0.605]
#  [1.6   0.6  ]
#  [1.685 0.605]
#  [1.775 0.615]
#  [1.86  0.635]
#  [1.94  0.66 ]
#  [2.025 0.695]
#  [2.1   0.735]
#  [2.175 0.78 ]
#  [2.245 0.835]
#  [2.305 0.895]
#  [2.365 0.955]
#  [2.42  1.025]
#  [2.465 1.1  ]
#  [2.505 1.175]
#  [2.54  1.26 ]
#  [2.565 1.34 ]
#  [2.585 1.425]
#  [2.595 1.515]
#  [2.6   1.6  ]
#  [2.595 1.685]
#  [2.585 1.775]
#  [2.565 1.86 ]
#  [2.54  1.94 ]
#  [2.505 2.025]
#  [2.465 2.1  ]
#  [2.42  2.175]
#  [2.365 2.245]
#  [2.305 2.305]
#  [2.245 2.365]
#  [2.175 2.42 ]
#  [2.1   2.465]
#  [2.025 2.505]
#  [1.94  2.54 ]
#  [1.86  2.565]
#  [1.775 2.585]
#  [1.685 2.595]
#  [1.6   2.6  ]
#  [1.515 2.595]
#  [1.425 2.585]
#  [1.34  2.565]
#  [1.26  2.54 ]
#  [1.175 2.505]
#  [1.1   2.465]
#  [1.025 2.42 ]
#  [0.955 2.365]
#  [0.895 2.305]
#  [0.835 2.245]
#  [0.78  2.175]
#  [0.735 2.1  ]
#  [0.695 2.025]
#  [0.66  1.94 ]
#  [0.635 1.86 ]
#  [0.615 1.775]
#  [0.605 1.685]
#  [0.6   1.6  ]], r: 1, rotate90_edge: <function rotate90_edge at 0x7b4fca5c3ec0>, rotate90_plate: <function rotate90_plate at 0x7b4fca5c3f60>, rotate90_point: <function rotate90_point at 0x7b4fca5c3e20>, rx: <function rx at 0x7b4fca42cc20>, rx_steps: <function rx_steps at 0x7b4fca42cd60>, snapshot: <function snapshot at 0x7b4fca42c360>, sphere: <function sphere at 0x7b4fca42c680>, src_steps: <function src_steps at 0x7b4fca42ccc0>, sys: <module 'sys' (built-in)>, theta: [0.         0.08726646 0.17453293 0.26179939 0.34906585 0.43633231
#  0.52359878 0.61086524 0.6981317  0.78539816 0.87266463 0.95993109
#  1.04719755 1.13446401 1.22173048 1.30899694 1.3962634  1.48352986
#  1.57079633 1.65806279 1.74532925 1.83259571 1.91986218 2.00712864
#  2.0943951  2.18166156 2.26892803 2.35619449 2.44346095 2.53072742
#  2.61799388 2.70526034 2.7925268  2.87979327 2.96705973 3.05432619
#  3.14159265 3.22885912 3.31612558 3.40339204 3.4906585  3.57792497
#  3.66519143 3.75245789 3.83972435 3.92699082 4.01425728 4.10152374
#  4.1887902  4.27605667 4.36332313 4.45058959 4.53785606 4.62512252
#  4.71238898 4.79965544 4.88692191 4.97418837 5.06145483 5.14872129
#  5.23598776 5.32325422 5.41052068 5.49778714 5.58505361 5.67232007
#  5.75958653 5.84685299 5.93411946 6.02138592 6.10865238 6.19591884
#  6.28318531], time_window: <function time_window at 0x7b4fca42c180>, transmission_line: <function transmission_line at 0x7b4fca42cb80>, triangle: <function triangle at 0x7b4fca42c540>, voltage_source: <function voltage_source at 0x7b4fca42cae0>, waveform: <function waveform at 0x7b4fca42c900>, x: [2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6       ], xq: [2.6   2.595 2.585 2.565 2.54  2.505 2.465 2.42  2.365 2.305 2.245 2.175
#  2.1   2.025 1.94  1.86  1.775 1.685 1.6   1.515 1.425 1.34  1.26  1.175
#  1.1   1.025 0.955 0.895 0.835 0.78  0.735 0.695 0.66  0.635 0.615 0.605
#  0.6   0.605 0.615 0.635 0.66  0.695 0.735 0.78  0.835 0.895 0.955 1.025
#  1.1   1.175 1.26  1.34  1.425 1.515 1.6   1.685 1.775 1.86  1.94  2.025
#  2.1   2.175 2.245 2.305 2.365 2.42  2.465 2.505 2.54  2.565 2.585 2.595
#  2.6  ], y: [1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6       ], yq: [1.6   1.685 1.775 1.86  1.94  2.025 2.1   2.175 2.245 2.305 2.365 2.42
#  2.465 2.505 2.54  2.565 2.585 2.595 2.6   2.595 2.585 2.565 2.54  2.505
#  2.465 2.42  2.365 2.305 2.245 2.175 2.1   2.025 1.94  1.86  1.775 1.685
#  1.6   1.515 1.425 1.34  1.26  1.175 1.1   1.025 0.955 0.895 0.835 0.78
#  0.735 0.695 0.66  0.635 0.615 0.605 0.6   0.605 0.615 0.635 0.66  0.695
#  0.735 0.78  0.835 0.895 0.955 1.025 1.1   1.175 1.26  1.34  1.425 1.515
#  1.6  ], z0: 376.7303134118051}
#
# Model title: Roots under Hete Soil Imaging
# Number of CPU (OpenMP) threads: 2
# GPU solving using: 0 - Tesla P100-PCIE-16GB
# Spatial discretisation: 0.005 x 0.005 x 0.005m
# Domain size: 3.2 x 1.7 x 3.2m (640 x 340 x 640 = 1.39264e+08 cells)
# Mode: 3D
# Time step (at CFL limit): 9.62917e-12 secs
# Time window: 3e-08 secs (3117 iterations)
#
# Waveform my_gaussian of type gaussian with maximum amplitude scaling 1, frequency 5e+08Hz created.
# Hertzian dipole with polarity y at 0.635m, 1.25m, 1.34m, using waveform my_gaussian created.
# Receiver at 0.615m, 1.25m, 1.425m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material confined_material with eps_r=5.24, sigma=0.001 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Mixing model (Peplinski) used to create hete_soil with sand fraction 0.3, clay fraction 0.7, bulk density 2g/cm3, sand particle density 2.66g/cm3, and water volumetric fraction 0.01 to 0.15 created.
#
# Memory (RAM) required: ~9.96GB host + ~9.96GB GPU
#
# Fractal box my_fractal_box from 0.1m, 0.1m, 0.1m, to 3.1m, 1m, 3.1m with hete_soil, fractal dimension 1.5, fractal weightings 1, 1, 1, fractal seeding 42, with 20 material(s) created, dielectric smoothing is off.
# Box from 0.1m, 1m, 0.1m, to 3.1m, 1.15m, 3.1m of material(s) confined_material created, dielectric smoothing is on.
# Material Object0{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Object1{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry objects from file (voxels only) test.h5 inserted at 0.6m, 0.1m, 0.6m, with corresponding materials file Object_materials.txt.
# Processing geometry related cmds: 100%|████████| 3/3 [00:21<00:00,  7.06s/cmds]
#
# PML: formulation: HORIPML, order: 1, thickness: 20
# Building PML boundaries: 100%|███████████████████| 6/6 [00:06<00:00,  1.03s/it]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:29<00:00, 14.96s/it]
#
# Memory (RAM) required - updated (dispersive): ~13.3GB
#
#
# Materials:
#     |                                                    |                     |         | sigma     | Delta     | tau       | omega | delta | gamma |      | sigma*  | Dielectric
#  ID | Name                                               | Type                | eps_r   | [S/m]     | eps_r     | [s]       | [Hz]  | [Hz]  | [Hz]  | mu_r | [Ohm/m] | smoothable
# ----+----------------------------------------------------+---------------------+---------+-----------+-----------+-----------+-------+-------+-------+------+---------+------------
#   0 | pec                                                | builtin             | 1       | inf       |           |           |       |       |       | 1    | 0       | False
#   1 | free_space                                         | builtin             | 1       | 0         |           |           |       |       |       | 1    | 0       | True
#   2 | confined_material                                  |                     | 5.24    | 0.001     |           |           |       |       |       | 1    | 0       | True
#   3 | |0.0137|                                           | debye               | 3.98341 | 0.0155417 | 0.0779246 | 9.231e-12 |       |       |       | 1    | 0       | False
#   4 | |0.0211|                                           | debye               | 4.243   | 0.0201373 | 0.155333  | 9.231e-12 |       |       |       | 1    | 0       | False
#   5 | |0.0284|                                           | debye               | 4.49387 | 0.02412   | 0.251173  | 9.231e-12 |       |       |       | 1    | 0       | False
#   6 | |0.0358|                                           | debye               | 4.73764 | 0.0277064 | 0.363321  | 9.231e-12 |       |       |       | 1    | 0       | False
#   7 | |0.0432|                                           | debye               | 4.97542 | 0.0310078 | 0.490329  | 9.231e-12 |       |       |       | 1    | 0       | False
#   8 | |0.0505|                                           | debye               | 5.20804 | 0.0340908 | 0.631118  | 9.231e-12 |       |       |       | 1    | 0       | False
#   9 | |0.0579|                                           | debye               | 5.43612 | 0.036999  | 0.784846  | 9.231e-12 |       |       |       | 1    | 0       | False
#  10 | |0.0653|                                           | debye               | 5.66017 | 0.0397628 | 0.950824  | 9.231e-12 |       |       |       | 1    | 0       | False
#  11 | |0.0726|                                           | debye               | 5.88059 | 0.0424046 | 1.12848   | 9.231e-12 |       |       |       | 1    | 0       | False
# ...
#  [1.26  0.66 ]
#  [1.26  2.54 ]
#  [1.34  0.635]
#  [1.34  2.565]
#  [1.425 0.615]
#  [1.425 2.585]
#  [1.515 0.605]
#  [1.515 2.595]
#  [1.6   0.6  ]
#  [1.6   2.6  ]
#  [1.685 0.605]
#  [1.685 2.595]
#  [1.775 0.615]
#  [1.775 2.585]
#  [1.86  0.635]
#  [1.86  2.565]
#  [1.94  0.66 ]
#  [1.94  2.54 ]
#  [2.025 0.695]
#  [2.025 2.505]
#  [2.1   0.735]
#  [2.1   2.465]
#  [2.175 0.78 ]
#  [2.175 2.42 ]
#  [2.245 0.835]
#  [2.245 2.365]
#  [2.305 0.895]
#  [2.305 2.305]
#  [2.365 0.955]
#  [2.365 2.245]
#  [2.42  1.025]
#  [2.42  2.175]
#  [2.465 1.1  ]
#  [2.465 2.1  ]
#  [2.505 1.175]
#  [2.505 2.025]
#  [2.54  1.26 ]
#  [2.54  1.94 ]
#  [2.565 1.34 ]
#  [2.565 1.86 ]
#  [2.585 1.425]
#  [2.585 1.775]
#  [2.595 1.515]
#  [2.595 1.685]
#  [2.6   1.6  ]], angles: [ 0.          0.08522023  0.17583028  0.26318054  0.3470616   0.43904407
#   0.52411193  0.61154396  0.70049637  0.78539816  0.87029996  0.95925237
#   1.04668439  1.13175225  1.22373472  1.30761579  1.39496605  1.4855761
#   1.57079633  1.65601656  1.7466266   1.83397686  1.91785793  2.0098404
#   2.09490826  2.18234029  2.2712927   2.35619449  2.44109628  2.53004869
#   2.61748072  2.70254858  2.79453105  2.87841212  2.96576238  3.05637242
#   3.14159265 -3.05637242 -2.96576238 -2.87841212 -2.79453105 -2.70254858
#  -2.61748072 -2.53004869 -2.44109628 -2.35619449 -2.2712927  -2.18234029
#  -2.09490826 -2.0098404  -1.91785793 -1.83397686 -1.7466266  -1.65601656
#  -1.57079633 -1.4855761  -1.39496605 -1.30761579 -1.22373472 -1.13175225
#  -1.04668439 -0.95925237 -0.87029996 -0.78539816 -0.70049637 -0.61154396
#  -0.52411193 -0.43904407 -0.3470616  -0.26318054 -0.17583028 -0.08522023], box: <function box at 0x7b4fca42c5e0>, c: 299792458.0, command: <function command at 0x7b4fca5c3c40>, current_model_run: 72, cx: 1.6, cy: 1.6, cylinder: <function cylinder at 0x7b4fca42c720>, cylindrical_sector: <function cylindrical_sector at 0x7b4fca42c7c0>, delta: 0.005, domain: <function domain at 0x7b4fca42c040>, dx_dy_dz: <function dx_dy_dz at 0x7b4fca42c0e0>, e0: 8.8541878188e-12, edge: <function edge at 0x7b4fca42c400>, excitation_file: <function excitation_file at 0x7b4fca42c860>, geometry_objects_read: <function geometry_objects_read at 0x7b4fca42ce00>, geometry_view: <function geometry_view at 0x7b4fca42c2c0>, hertzian_dipole: <function hertzian_dipole at 0x7b4fca42c9a0>, idx: [36 37 35 38 34 39 33 40 32 41 31 42 30 43 29 44 28 45 27 46 26 47 25 48
#  24 49 23 50 22 51 21 52 20 53 19 54 18 55 17 56 16 57 15 58 14 59 13 60
#  12 61 11 62 10 63  9 64  8 65  7 66  6 67  5 68  4 69  3 70  2 71  1  0], inputfile: /kaggle/working/roots_3d/circular_scan.in, m0: 1.25663706127e-06, magnetic_dipole: <function magnetic_dipole at 0x7b4fca42ca40>, material: <function material at 0x7b4fca42c220>, namedtuple: <function namedtuple at 0x7b4fecf59080>, np: <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>, number_model_runs: 72, plate: <function plate at 0x7b4fca42c4a0>, points: [[0.605 1.515]
#  [0.615 1.425]
#  [0.635 1.34 ]
#  [0.66  1.26 ]
#  [0.695 1.175]
#  [0.735 1.1  ]
#  [0.78  1.025]
#  [0.835 0.955]
#  [0.895 0.895]
#  [0.955 0.835]
#  [1.025 0.78 ]
#  [1.1   0.735]
#  [1.175 0.695]
#  [1.26  0.66 ]
#  [1.34  0.635]
#  [1.425 0.615]
#  [1.515 0.605]
#  [1.6   0.6  ]
#  [1.685 0.605]
#  [1.775 0.615]
#  [1.86  0.635]
#  [1.94  0.66 ]
#  [2.025 0.695]
#  [2.1   0.735]
#  [2.175 0.78 ]
#  [2.245 0.835]
#  [2.305 0.895]
#  [2.365 0.955]
#  [2.42  1.025]
#  [2.465 1.1  ]
#  [2.505 1.175]
#  [2.54  1.26 ]
#  [2.565 1.34 ]
#  [2.585 1.425]
#  [2.595 1.515]
#  [2.6   1.6  ]
#  [2.595 1.685]
#  [2.585 1.775]
#  [2.565 1.86 ]
#  [2.54  1.94 ]
#  [2.505 2.025]
#  [2.465 2.1  ]
#  [2.42  2.175]
#  [2.365 2.245]
#  [2.305 2.305]
#  [2.245 2.365]
#  [2.175 2.42 ]
#  [2.1   2.465]
#  [2.025 2.505]
#  [1.94  2.54 ]
#  [1.86  2.565]
#  [1.775 2.585]
#  [1.685 2.595]
#  [1.6   2.6  ]
#  [1.515 2.595]
#  [1.425 2.585]
#  [1.34  2.565]
#  [1.26  2.54 ]
#  [1.175 2.505]
#  [1.1   2.465]
#  [1.025 2.42 ]
#  [0.955 2.365]
#  [0.895 2.305]
#  [0.835 2.245]
#  [0.78  2.175]
#  [0.735 2.1  ]
#  [0.695 2.025]
#  [0.66  1.94 ]
#  [0.635 1.86 ]
#  [0.615 1.775]
#  [0.605 1.685]
#  [0.6   1.6  ]], r: 1, rotate90_edge: <function rotate90_edge at 0x7b4fca5c3ec0>, rotate90_plate: <function rotate90_plate at 0x7b4fca5c3f60>, rotate90_point: <function rotate90_point at 0x7b4fca5c3e20>, rx: <function rx at 0x7b4fca42cc20>, rx_steps: <function rx_steps at 0x7b4fca42cd60>, snapshot: <function snapshot at 0x7b4fca42c360>, sphere: <function sphere at 0x7b4fca42c680>, src_steps: <function src_steps at 0x7b4fca42ccc0>, sys: <module 'sys' (built-in)>, theta: [0.         0.08726646 0.17453293 0.26179939 0.34906585 0.43633231
#  0.52359878 0.61086524 0.6981317  0.78539816 0.87266463 0.95993109
#  1.04719755 1.13446401 1.22173048 1.30899694 1.3962634  1.48352986
#  1.57079633 1.65806279 1.74532925 1.83259571 1.91986218 2.00712864
#  2.0943951  2.18166156 2.26892803 2.35619449 2.44346095 2.53072742
#  2.61799388 2.70526034 2.7925268  2.87979327 2.96705973 3.05432619
#  3.14159265 3.22885912 3.31612558 3.40339204 3.4906585  3.57792497
#  3.66519143 3.75245789 3.83972435 3.92699082 4.01425728 4.10152374
#  4.1887902  4.27605667 4.36332313 4.45058959 4.53785606 4.62512252
#  4.71238898 4.79965544 4.88692191 4.97418837 5.06145483 5.14872129
#  5.23598776 5.32325422 5.41052068 5.49778714 5.58505361 5.67232007
#  5.75958653 5.84685299 5.93411946 6.02138592 6.10865238 6.19591884
#  6.28318531], time_window: <function time_window at 0x7b4fca42c180>, transmission_line: <function transmission_line at 0x7b4fca42cb80>, triangle: <function triangle at 0x7b4fca42c540>, voltage_source: <function voltage_source at 0x7b4fca42cae0>, waveform: <function waveform at 0x7b4fca42c900>, x: [2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6       ], xq: [2.6   2.595 2.585 2.565 2.54  2.505 2.465 2.42  2.365 2.305 2.245 2.175
#  2.1   2.025 1.94  1.86  1.775 1.685 1.6   1.515 1.425 1.34  1.26  1.175
#  1.1   1.025 0.955 0.895 0.835 0.78  0.735 0.695 0.66  0.635 0.615 0.605
#  0.6   0.605 0.615 0.635 0.66  0.695 0.735 0.78  0.835 0.895 0.955 1.025
#  1.1   1.175 1.26  1.34  1.425 1.515 1.6   1.685 1.775 1.86  1.94  2.025
#  2.1   2.175 2.245 2.305 2.365 2.42  2.465 2.505 2.54  2.565 2.585 2.595
#  2.6  ], y: [1.6        1.68715574 1.77364818 1.85881905 1.94202014 2.02261826
#  2.1        2.17357644 2.24278761 2.30710678 2.36604444 2.41915204
#  2.4660254  2.50630779 2.53969262 2.56592583 2.58480775 2.5961947
#  2.6        2.5961947  2.58480775 2.56592583 2.53969262 2.50630779
#  2.4660254  2.41915204 2.36604444 2.30710678 2.24278761 2.17357644
#  2.1        2.02261826 1.94202014 1.85881905 1.77364818 1.68715574
#  1.6        1.51284426 1.42635182 1.34118095 1.25797986 1.17738174
#  1.1        1.02642356 0.95721239 0.89289322 0.83395556 0.78084796
#  0.7339746  0.69369221 0.66030738 0.63407417 0.61519225 0.6038053
#  0.6        0.6038053  0.61519225 0.63407417 0.66030738 0.69369221
#  0.7339746  0.78084796 0.83395556 0.89289322 0.95721239 1.02642356
#  1.1        1.17738174 1.25797986 1.34118095 1.42635182 1.51284426
#  1.6       ], yq: [1.6   1.685 1.775 1.86  1.94  2.025 2.1   2.175 2.245 2.305 2.365 2.42
#  2.465 2.505 2.54  2.565 2.585 2.595 2.6   2.595 2.585 2.565 2.54  2.505
#  2.465 2.42  2.365 2.305 2.245 2.175 2.1   2.025 1.94  1.86  1.775 1.685
#  1.6   1.515 1.425 1.34  1.26  1.175 1.1   1.025 0.955 0.895 0.835 0.78
#  0.735 0.695 0.66  0.635 0.615 0.605 0.6   0.605 0.615 0.635 0.66  0.695
#  0.735 0.78  0.835 0.895 0.955 1.025 1.1   1.175 1.26  1.34  1.425 1.515
#  1.6  ], z0: 376.7303134118051}
#
# Model title: Roots under Hete Soil Imaging
# Number of CPU (OpenMP) threads: 2
# GPU solving using: 0 - Tesla P100-PCIE-16GB
# Spatial discretisation: 0.005 x 0.005 x 0.005m
# Domain size: 3.2 x 1.7 x 3.2m (640 x 340 x 640 = 1.39264e+08 cells)
# Mode: 3D
# Time step (at CFL limit): 9.62917e-12 secs
# Time window: 3e-08 secs (3117 iterations)
#
# Waveform my_gaussian of type gaussian with maximum amplitude scaling 1, frequency 5e+08Hz created.
# Hertzian dipole with polarity y at 0.6m, 1.25m, 1.6m, using waveform my_gaussian created.
# Receiver at 0.605m, 1.25m, 1.685m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material confined_material with eps_r=5.24, sigma=0.001 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Mixing model (Peplinski) used to create hete_soil with sand fraction 0.3, clay fraction 0.7, bulk density 2g/cm3, sand particle density 2.66g/cm3, and water volumetric fraction 0.01 to 0.15 created.
#
# Memory (RAM) required: ~9.96GB host + ~9.96GB GPU
#
# Fractal box my_fractal_box from 0.1m, 0.1m, 0.1m, to 3.1m, 1m, 3.1m with hete_soil, fractal dimension 1.5, fractal weightings 1, 1, 1, fractal seeding 42, with 20 material(s) created, dielectric smoothing is off.
# Box from 0.1m, 1m, 0.1m, to 3.1m, 1.15m, 3.1m of material(s) confined_material created, dielectric smoothing is on.
# Material Object0{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Object1{Object_materials} with eps_r=24, sigma=0.0002 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry objects from file (voxels only) test.h5 inserted at 0.6m, 0.1m, 0.6m, with corresponding materials file Object_materials.txt.
# Processing geometry related cmds: 100%|████████| 3/3 [00:21<00:00,  7.08s/cmds]
#
# PML: formulation: HORIPML, order: 1, thickness: 20
# Building PML boundaries: 100%|███████████████████| 6/6 [00:06<00:00,  1.07s/it]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:30<00:00, 15.17s/it]
#
# Memory (RAM) required - updated (dispersive): ~13.3GB
#
#
# Materials:
#     |                                                    |                     |         | sigma     | Delta     | tau       | omega | delta | gamma |      | sigma*  | Dielectric
#  ID | Name                                               | Type                | eps_r   | [S/m]     | eps_r     | [s]       | [Hz]  | [Hz]  | [Hz]  | mu_r | [Ohm/m] | smoothable
# ----+----------------------------------------------------+---------------------+---------+-----------+-----------+-----------+-------+-------+-------+------+---------+------------
#   0 | pec                                                | builtin             | 1       | inf       |           |           |       |       |       | 1    | 0       | False
#   1 | free_space                                         | builtin             | 1       | 0         |           |           |       |       |       | 1    | 0       | True
#   2 | confined_material                                  |                     | 5.24    | 0.001     |           |           |       |       |       | 1    | 0       | True
#   3 | |0.0137|                                           | debye               | 3.98341 | 0.0155417 | 0.0779246 | 9.231e-12 |       |       |       | 1    | 0       | False
#   4 | |0.0211|                                           | debye               | 4.243   | 0.0201373 | 0.155333  | 9.231e-12 |       |       |       | 1    | 0       | False
#   5 | |0.0284|                                           | debye               | 4.49387 | 0.02412   | 0.251173  | 9.231e-12 |       |       |       | 1    | 0       | False
#   6 | |0.0358|                                           | debye               | 4.73764 | 0.0277064 | 0.363321  | 9.231e-12 |       |       |       | 1    | 0       | False
#   7 | |0.0432|                                           | debye               | 4.97542 | 0.0310078 | 0.490329  | 9.231e-12 |       |       |       | 1    | 0       | False
#   8 | |0.0505|                                           | debye               | 5.20804 | 0.0340908 | 0.631118  | 9.231e-12 |       |       |       | 1    | 0       | False
#   9 | |0.0579|                                           | debye               | 5.43612 | 0.036999  | 0.784846  | 9.231e-12 |       |       |       | 1    | 0       | False
#  10 | |0.0653|                                           | debye               | 5.66017 | 0.0397628 | 0.950824  | 9.231e-12 |       |       |       | 1    | 0       | False
#  11 | |0.0726|                                           | debye               | 5.88059 | 0.0424046 | 1.12848   | 9.231e-12 |       |       |       | 1    | 0       | False
#  12 | |0.0800|                                           | debye               | 6.09774 | 0.0449416 | 1.31733   | 9.231e-12 |       |       |       | 1    | 0       | False
#  13 | |0.0874|                                           | debye               | 6.3119  | 0.0473869 | 1.51694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  14 | |0.0947|                                           | debye               | 6.52331 | 0.0497512 | 1.72694   | 9.231e-12 |       |       |       | 1    | 0       | False
#  15 | |0.1021|                                           | debye               | 6.7322  | 0.0520433 | 1.94701   | 9.231e-12 |       |       |       | 1    | 0       | False
#  16 | |0.1095|                                           | debye               | 6.93874 | 0.0542703 | 2.17685   | 9.231e-12 |       |       |       | 1    | 0       | False
#  17 | |0.1168|                                           | debye               | 7.1431  | 0.0564383 | 2.41618   | 9.231e-12 |       |       |       | 1    | 0       | False
#  18 | |0.1242|                                           | debye               | 7.34543 | 0.0585524 | 2.66476   | 9.231e-12 |       |       |       | 1    | 0       | False
#  19 | |0.1316|                                           | debye               | 7.54585 | 0.0606171 | 2.92238   | 9.231e-12 |       |       |       | 1    | 0       | False
#  20 | |0.1389|                                           | debye               | 7.74449 | 0.0626362 | 3.18883   | 9.231e-12 |       |       |       | 1    | 0       | False
#  21 | |0.1463|                                           | debye               | 7.94144 | 0.064613  | 3.46391   | 9.231e-12 |       |       |       | 1    | 0       | False
#  22 | |0.1537|                                           | debye               | 8.1368  | 0.0665505 | 3.74745   | 9.231e-12 |       |       |       | 1    | 0       | False
#  23 | Object0{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  24 | Object1{Object_materials}                          | imported            | 24      | 0.0002    |           |           |       |       |       | 1    | 0       | True
#  25 | confined_material+confined_material+free_space+fre | dielectric-smoothed | 3.12    | 0.0005    |           |           |       |       |       | 1    | 0       | True
#  26 | free_space+confined_material+free_space+free_space | dielectric-smoothed | 2.06    | 0.00025   |           |           |       |       |       | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -1.81% in material 'Object0{Object_materials}' whose wavelength sampled by 7 cells. Maximum significant frequency estimated as 1.53261e+09Hz
#
# Output file: /kaggle/working/roots_3d/circular_scan72.out
#
# Running simulation, model 72/72: 100%|█████| 3117/3117 [04:08<00:00, 12.55it/s]
# Memory (RAM) used: ~6.01GB host + ~11GB GPU
# Solving time [HH:MM:SS]: 0:04:13.283312
#
# === Simulation completed in [HH:MM:SS]: 6:20:18.776138 ========================

# %%
import os
import zipfile

# Define the output archive name
final_zip_name = "/kaggle/working/Output_3D.zip"

# List of folders to include in the archive
folders_to_zip = [
    "/kaggle/working/ge4w3d/ObjImg_3D",
    "/kaggle/working/ge4w3d/Output_3D",
    "/kaggle/working/ge4w3d/BaseImg_3D",
    "/kaggle/working/ge4w3d/WallObj_3D"  # Add the fourth folder here
]

# Function to zip multiple folders into a single archive
def zip_folders(folders, zip_name):
    with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for folder in folders:
            for root, _, files in os.walk(folder):
                for file in files:
                    # Create archive paths
                    full_path = os.path.join(root, file)
                    relative_path = os.path.relpath(full_path, start=os.path.dirname(folder))
                    zipf.write(full_path, arcname=relative_path)
# Zip all folders into the final archive
zip_folders(folders_to_zip, final_zip_name)
print(f"All folders zipped into {final_zip_name}")
# Out:
# All folders zipped into /kaggle/working/Output_3D.zip

# %%
import sys
sys.exit("Stopping early due to condition.")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stopping early due to condition.
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
